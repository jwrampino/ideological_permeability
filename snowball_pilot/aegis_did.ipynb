# %% [markdown]
# Extract DID for Aegis to Insert in Config

# %%
from dotenv import load_dotenv
import os
from atproto import Client

load_dotenv()
c = Client()
c.login(os.environ['BSKY_HANDLE'], os.environ['BSKY_PASSWORD'])
print(c.app.bsky.labeler.get_services(params={'dids': ['aegis.bsky.social']}))
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from atproto import Client
# ----> 2 Client().app.bsky.labeler.get_services(params={'dids': ['aegis.bsky.social']})
#
# File c:\Users\jwram\anaconda3\envs\firehose_env\lib\site-packages\atproto_client\namespaces\sync_ns.py:4112, in AppBskyLabelerNamespace.get_services(self, params, **kwargs)
#    4097 """Get information about a list of labeler services.
#    4098
#    4099 Args:
#    (...)
#    4107     :class:`atproto.exceptions.AtProtocolError`: Base exception.
#    4108 """
#    4109 params_model = t.cast(
#    4110     'models.AppBskyLabelerGetServices.Params', get_or_create(params, models.AppBskyLabelerGetServices.Params)
#    4111 )
# -> 4112 response = self._client.invoke_query(
#    4113     'app.bsky.labeler.getServices', params=params_model, output_encoding='application/json', **kwargs
# ...
